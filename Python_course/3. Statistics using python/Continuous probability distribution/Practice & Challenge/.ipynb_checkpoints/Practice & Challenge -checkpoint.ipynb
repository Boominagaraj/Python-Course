# %% [markdown]
# ### Task-01

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

import scipy.stats as sts
import math
from scipy.stats import norm

# %% [markdown]
# ### 1- Randomly selected bill amount between USD55 and USD 80

# %%
mean=70
std=11.351
lower_p = 55
upper_p = 80
norm_p=np.arange(lower_p, upper_p)
prob_bill=norm.pdf(norm_p,mean, std)
print(sum(prob_bill))
# Out:
# 0.7127846264338699

# %% [markdown]
# ### 2- Randomly selected bill amount no more than USD40

# %%
mean=70
std=11.351
lower_p = 1
upper_p = 40
norm_p1=np.arange(lower_p, upper_p)
prob_bill1=norm.pdf(norm_p1,mean, std)
print(sum(prob_bill1))
# Out:
# 0.003595608320766236

# %% [markdown]
# ### Task-2

# %% [markdown]
# #### A-Extract data from the car riding data

# %%
df=pd.read_csv("DS1_C5_S5_SmartCarRiding_Data_Practice.csv")
df
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 0              -73.999512         40.723217                1
# 1              -73.994710         40.750325                1
# 2              -73.962565         40.772647                1
# 3              -73.965316         40.803349                3
# 4              -73.973082         40.761247                5
# ...                   ...               ...              ...
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1
#
# [200000 rows x 9 columns]

# %% [markdown]
# ### Population Distribution

# %%
sb.distplot(df["fare_amount"]);

# %% [markdown]
# #### C-Draw Samples Plots

# %%
fig, ax = plt.subplots(2,4, figsize=(15,8))
num = [10,30,1000,5000,10000,50000,100000,150000]
sample_df = pd.DataFrame()
data_s = []

for i in num:
  sample_df = df.sample(n=i, random_state=1)
  data_s.append(sample_df['fare_amount'].tolist())

data_s
k = 0
for i in range(0,2):
  for j in range(0,4):
    # ax[i,j].hist(data_s[k], bins=5)
    sb.distplot(data_s[k], ax=ax[i,j])
    ax[i,j].set_title("Sample of Size:"+str(len(data_s[k])))
    k = k+1

plt.show()

# %% [markdown]
# #### D-Random Sampling for 200

# %%
random_sample=df.sample(n=200,replace=True,random_state=1)
random_sample
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 128037    34880869    2010-12-26 14:32:56.0000001        49.57
# 5192      10514640   2012-11-27 21:28:00.00000038        14.00
# 50057     39371632  2010-08-23 22:09:00.000000158        12.90
# 109259    37753824    2013-10-09 08:22:30.0000003         6.00
# 73349     48099710    2012-01-17 20:23:07.0000001         6.10
# ...            ...                            ...          ...
# 119440    38653342  2011-01-15 13:29:00.000000149         7.70
# 176028    16314367   2009-04-23 13:26:00.00000062         4.50
# 38122     37151879  2013-12-19 20:57:00.000000160        13.00
# 15917      4467260    2012-08-14 02:52:26.0000001         4.50
# 20931     17816586   2014-04-25 08:10:00.00000088        10.00
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 128037  2010-12-26 14:32:56 UTC        -73.965069        40.791239
# 5192    2012-11-27 21:28:00 UTC        -73.776675        40.645348
# 50057   2010-08-23 22:09:00 UTC        -73.994013        40.724697
# 109259  2013-10-09 08:22:30 UTC        -73.981399        40.741402
# 73349   2012-01-17 20:23:07 UTC        -73.988700        40.748039
# ...                         ...               ...              ...
# 119440  2011-01-15 13:29:00 UTC        -73.966792        40.788865
# 176028  2009-04-23 13:26:00 UTC        -73.993047        40.743015
# 38122   2013-12-19 20:57:00 UTC        -73.978997        40.762238
# 15917   2012-08-14 02:52:26 UTC        -73.965087        40.714338
# 20931   2014-04-25 08:10:00 UTC        -73.981530        40.771372
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 128037         -73.782221         40.648726                1
# 5192           -73.819305         40.670327                2
# 50057          -73.994923         40.762680                1
# 109259         -73.991322         40.739277                1
# 73349          -74.003445         40.738223                2
# ...                   ...               ...              ...
# 119440         -73.981745         40.766047                1
# 176028         -73.982815         40.738575                5
# 38122          -73.987182         40.751058                1
# 15917          -73.957762         40.717726                1
# 20931            0.000000          0.000000                6
#
# [200 rows x 9 columns]

# %% [markdown]
# #### E-Calculate the Central Tendency

# %% [markdown]
# #####  Calculation of Population Parameter (Mean, Median, Standard Deviation)

# %%
p_mean = df['fare_amount'].mean()
p_median = df['fare_amount'].median()
p_std = df['fare_amount'].std()
p_skew = sts.skew(df['fare_amount'], bias = False)
p_kurt = sts.kurtosis(df['fare_amount'], bias = False)

print("Population mean is", p_mean)
print("Population median is", p_median)
print("Population standard deviation is", p_std)
print("Population skew is", p_skew)
print("Population kurtosis is", p_kurt)
# Out:
# Population mean is 11.359955250000002
# Population median is 8.5
# Population standard deviation is 9.901776225068813
# Population skew is 4.504846860602115
# Population kurtosis is 63.884314130640405

# %% [markdown]
# #####  Calculation of Sample Statistics (Mean, Median, Standard Deviation)

# %%
s_mean = random_sample['fare_amount'].mean()
s_median = random_sample['fare_amount'].median()
s_std = random_sample['fare_amount'].std()
s_skew = sts.skew(random_sample['fare_amount'], bias = False)
s_kurt = sts.kurtosis(random_sample['fare_amount'], bias = False)

print("Sample mean is", s_mean)
print("Sample median is", s_median)
print("Sample standard deviation is", s_std)
print("Sample skew is", s_skew)
print("Sample kurtosis is", s_kurt)
# Out:
# Sample mean is 11.2508
# Sample median is 8.5
# Sample standard deviation is 8.963919602114123
# Sample skew is 2.3576623704544124
# Sample kurtosis is 7.250475134814707

# %% [markdown]
# #### Probability & Sample  Distribution curve of population and sample

# %%
plt.figure(figsize=(15,8))

lower_p = p_mean - 4*p_std
upper_p = p_mean + 4*p_std

lower_s = s_mean - 4*s_std
upper_s = s_mean + 4*s_std

norm_p = np.arange(lower_p, upper_p)
norm_s = np.arange(lower_s, upper_s)

plt.subplot(1,2,1)
plt.plot(norm_p, norm.pdf(norm_p, p_mean, p_std), label = "Population", color = "blue")
plt.legend()
plt.xlabel("Fare Amount")
plt.ylabel("Probability")
plt.title("Probability Distribution Curve of Population")

plt.subplot(1,2,2)
plt.plot(norm_s, norm.pdf(norm_s, s_mean, s_std), label = "Sample", color = "red")
plt.legend()
plt.xlabel("Fare Amount")
plt.ylabel("Probability")
plt.title("Probability Distribution Curve of Sample")
plt.show()

# %% [markdown]
# ### Interpretation

# %%
#  As per my report comparing the Population and Sample are approximately equal 
#  200 sample are perfect for Standard Normal Distribution
#  sampling distribution will tend to normal distribution
#  Sample mean ~ Population mean
#  As size of sample is increasing sample standard deviation will decrease

# %% [markdown]
# # Challenge

# %% [markdown]
# ## Income Tax return for Taxpayers

# %% [markdown]
# #### Task-1

# %%
mean=1332
sd=725
norm_p=2000
prob_bill=norm.pdf(norm_p,mean, sd)
prob_bill
# Out:
# 0.0003599375172310294

# %% [markdown]
# #### Task-2

# %% [markdown]
# # High-End Video Games

# %%
Games_df=pd.read_csv("DS1_C5_S5_Computers_Data_Challenge.csv")
Games_df
# Out:
#       index  price  speed    hd  ram  screen   cd multi premium  ads  trend
# 0         1   1499     25    80    4      14   no    no     yes   94      1
# 1         2   1795     33    85    2      14   no    no     yes   94      1
# 2         3   1595     25   170    4      15   no    no     yes   94      1
# 3         4   1849     25   170    8      14   no    no      no   94      1
# 4         5   3295     33   340   16      14   no    no     yes   94      1
# ...     ...    ...    ...   ...  ...     ...  ...   ...     ...  ...    ...
# 6254   6255   1690    100   528    8      15   no    no     yes   39     35
# 6255   6256   2223     66   850   16      15  yes   yes     yes   39     35
# 6256   6257   2654    100  1200   24      15  yes    no     yes   39     35
# 6257   6258   2195    100   850   16      15  yes    no     yes   39     35
# 6258   6259   2490    100   850   16      17  yes    no     yes   39     35
#
# [6259 rows x 11 columns]

# %% [markdown]
# ### Task-1

# %%
Games_sample=Games_df[Games_df["price"]<=4000].sample(n=50,replace=True,random_state=1)
Games_sample
# Out:
#       index  price  speed    hd  ram  screen   cd multi premium  ads  trend
# 5187   5188   1429     33   424    4      15   no    no     yes  182     24
# 239     240   3795     66   500    8      14   no    no     yes  100      3
# 4006   4007   1890     33   340    4      17   no    no     yes  273     18
# 5222   5223   1728     66   428    4      17   no    no     yes  182     24
# 913     914   2299     66   245    8      14   no    no     yes  249      7
# 2789   2790   2620     66   528    8      14  yes    no     yes  292     14
# 2921   2922   1344     25   107    2      14   no    no     yes  267     15
# 5086   5087   2339     66   540    8      17   no    no     yes  182     24
# 148     149   1975     33   250    8      14   no    no     yes   95      2
# 4252   4253   1649     66   212    4      15   no    no     yes  248     20
# 2823   2824   1725     33   212    4      14   no    no     yes  292     14
# 3488   3489   2290     66   426    8      14  yes    no     yes  339     17
# 1218   1219   1795     33   214    8      14   no    no     yes  298      8
# 5426   5427   1854    100   340    4      14   no    no     yes  152     26
# 5404   5405   1998     66   730    8      15  yes   yes     yes  152     26
# 4481   4482   1288     33   340    4      15   no    no     yes  248     20
# 2988   2989   1894     33   214    4      14  yes   yes     yes  267     15
# 2542   2543   2344     33   426    8      14  yes    no     yes  292     14
# 256     257   3035     50   250    8      17   no    no     yes  100      3
# 3588   3589   2355     66   340    8      15  yes    no     yes  339     17
# 4794   4795   1199     33   428    4      15   no    no     yes  162     22
# 567     568   1390     25   107    2      15   no    no     yes  176      6
# 2654   2655   2479     66   212    4      15   no    no      no  292     14
# 3075   3076   2544     25   528   16      14  yes    no     yes  267     15
# 761     762   1590     25   107    2      14   no    no     yes  249      7
# 1549   1550   2749     33   340    4      15   no    no     yes  283     10
# 3576   3577   2343     66   426    8      14  yes   yes     yes  339     17
# 1911   1912   1908     33   120    4      14   no    no      no  259     11
# 1123   1124   2039     66   170    4      14  yes   yes     yes  298      8
# 6151   6152   2554     75  1200   24      15  yes    no     yes   40     33
# 1041   1042   1890     50   107    2      14   no    no     yes  298      8
# 4443   4444   2049     33   270    4      14   no    no      no  248     20
# 2903   2904   1944     33   214    4      14   no    no     yes  267     15
# 3632   3633   2275     66   530    8      15  yes    no     yes  339     17
# 1354   1355   2590     66   426    8      15   no    no     yes  246      9
# 2587   2588   2594     50   426    8      14  yes   yes     yes  292     14
# 6046   6047   2344     66  1000   16      15  yes    no     yes   52     31
# 4440   4441   2994    100   720   16      14  yes    no     yes  248     20
# 5414   5415   1299     66   428    4      14   no    no     yes  152     26
# 735     736   1890     33   107    2      14   no    no     yes  249      7
# 436     437   2805     33   250    8      17   no    no     yes  139      5
# 4100   4101   2040     33   426    8      14  yes    no     yes  225     19
# 4759   4760   1195     25   214    4      14   no    no     yes  162     22
# 547     548   2599     50   450    8      15   no    no     yes  176      6
# 1107   1108   2170     33   340    8      14  yes    no     yes  298      8
# 5537   5538   1644     50   340    4      14   no    no     yes  152     26
# 1499   1500   1890     33   214    4      14   no    no     yes  246      9
# 3659   3660   1595     33   340    8      14   no    no     yes  339     17
# 1354   1355   2590     66   426    8      15   no    no     yes  246      9
# 4639   4640   1818     66   340    4      17   no    no     yes  205     21

# %% [markdown]
# ### Task-2

# %% [markdown]
# #### Calculate the Central Tendency

# %% [markdown]
# #####  Calculation of Population Parameter (Mean, Median, Standard Deviation)

# %%
p_mean = Games_df['price'].mean()
p_median = Games_df['price'].median()
p_std = Games_df['price'].std()
p_skew = sts.skew(Games_df['price'], bias = False)
p_kurt = sts.kurtosis(Games_df['price'], bias = False)

print("Population mean is", p_mean)
print("Population median is", p_median)
print("Population standard deviation is", p_std)
print("Population skew is", p_skew)
print("Population kurtosis is", p_kurt)
# Out:
# Population mean is 2219.576609682058
# Population median is 2144.0
# Population standard deviation is 580.8039556527048
# Population skew is 0.7117247480608602
# Population kurtosis is 0.7304170367653207

# %% [markdown]
# #####  Calculation of Sample Statistics (Mean, Median, Standard Deviation)

# %%
s_mean1 = Games_sample['price'].mean()
s_median = Games_sample['price'].median()
s_std1 = Games_sample['price'].std()
s_skew = sts.skew(Games_sample['price'], bias = False)
s_kurt = sts.kurtosis(Games_sample['price'], bias = False)

print("Population mean is", s_mean1)
print("Population median is", s_median)
print("Population standard deviation is", s_std1)
print("Population skew is", s_skew)
print("Population kurtosis is", s_kurt)
# Out:
# Population mean is 2093.12
# Population median is 2018.5
# Population standard deviation is 532.1603885894491
# Population skew is 0.5600118238894103
# Population kurtosis is 0.7958678208509138

# %%
plt.figure(figsize=(15,8))

lower_p1 = p_mean - 4*p_std
upper_p1 = p_mean + 4*p_std

lower_s1 = s_mean1 - 4*s_std1
upper_s1 = s_mean1 + 4*s_std1

norm_p1 = np.arange(lower_p1, upper_p1)
norm_s1 = np.arange(lower_s1, upper_s1)

plt.subplot(1,2,1)
plt.plot(norm_p1, norm.pdf(norm_p1, p_mean, p_std), label = "Population", color = "blue")
plt.legend()
plt.xlabel("Fare Amount")
plt.ylabel("Probability")
plt.title("Probability Distribution Curve of Population")

plt.subplot(1,2,2)
plt.plot(norm_s1, norm.pdf(norm_s1, s_mean1, s_std1), label = "Sample", color = "red")
plt.legend()
plt.xlabel("Fare Amount")
plt.ylabel("Probability")
plt.title("Probability Distribution Curve of Sample")
plt.show()

# %%
#  As per my report comparing the Population and Sample are not equal
#  Sample mean not equal Population mean
#  As size of sample is decrease compare to population standard deviation

# %% [markdown]
# ## Task-3

# %% [markdown]
# #### Normal Distribution plot of the population

# %%
sb.distplot(Games_df["price"]);

# %% [markdown]
# #### Normal Distribution plot of the Sample

# %%
sb.distplot(Games_sample["price"]);

# %% [markdown]
# ## Task-5

# %% [markdown]
# #### Calculate the Z-Score

# %%
import statistics as st
standard_data = []
for i in norm_s1:
  zs = (i - s_mean1)/s_std1
  standard_data.append(zs)

ZScore=sts.norm.pdf(standard_data, st.mean(standard_data), st.stdev(standard_data))
print(sum(ZScore))
# Out:
# 486.72662554855293

# %% [markdown]
# ## Task-6

# %% [markdown]
# ### Calculate probality values of the z-score

# %%
x = 4000
z_score_85000 = (x-p_mean)/p_std
prob = 1 - sts.norm.cdf(z_score_85000)
print("Probability of 4000 is", prob)
# Out:
# Probability of 4000 is 0.0010867266835357103

# %% [markdown]
# ## Task-7

# %% [markdown]
# ### Standard normal Distribution

# %%
plt.plot(norm_s1,ZScore, color = "red")
plt.xlabel("Z-Scores")
plt.ylabel("Probability of ZScore")
plt.title("Standard Normal Distribution")
plt.show()
