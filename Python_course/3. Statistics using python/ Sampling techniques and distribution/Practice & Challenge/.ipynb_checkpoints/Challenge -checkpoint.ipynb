# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import statistics as st
from scipy.stats import skew,norm,kurtosis

# %%
df=pd.read_csv('DS1_C5_S3_GamesSales_Data_Challenge.csv')
df
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2016            Action
# 1           Call of Duty: Black Ops 3  2017           Shooter
# 2               Red Dead Redemption 2  2020  Action-Adventure
# 3                  Call of Duty: WWII  2019           Shooter
# 4                             FIFA 18  2019            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2019      Role-Playing
# 705                         Teslagrad  2016          Platform
# 706  Darius Burst: Chronicle Saviours  2019            Action
# 707   The Escapists: The Walking Dead  2018            Action
# 708                    Super Meat Boy  2018          Platform
#
#                Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0         Rockstar Games                    6.06             9.71
# 1             Activision                    6.18             6.05
# ...

# %% [markdown]
# ### Task-1

# %%
P_female = 0.46
P_part_time_given_female = 0.25
P_part_time = 0.174

P_female_and_part_time = P_female * P_part_time_given_female
P_female_given_part_time = P_female_and_part_time / P_part_time

P_female_given_part_time
# Out:
# 0.6609195402298851

# %% [markdown]
# ### Task-2

# %%
# 70% Productivity Increase by Reducing Noise is refered as P_A
# 67% Productivity Increase by More Storage space is refered as P_B
# 70% Productivity Increase by Reducing Noise and More Storage space is refered as P_A_and_B
P_A = 0.70
P_B = 0.67
P_A_and_B = 0.56

P_B_given_A = P_A_and_B / P_A
P_B_given_A
# Out:
# 0.8000000000000002

# %% [markdown]
# ### 3.1.1- Random sampling without replacement

# %%
random_sample = df.sample(n = 20, replace = False, random_state = 42)
random_sample
# Out:
#                                                   Game  Year  \
# 294                              Robinson: The Journey  2018
# 256                            Sniper: Ghost Warrior 3  2019
# 613                                       Koihime Enbu  2018
# 357           MXGP 3: The Official Motocross Videogame  2019
# 248                                  Batman: Arkham VR  2018
# 164               Assassin's Creed The Ezio Collection  2018
# 499                                           Terraria  2016
# 84                                        Dishonored 2  2018
# 54                Metal Gear Solid V: The Phantom Pain  2017
# 412                             Danganronpa 1o2 Reload  2019
# 551                         Sengoku Basara 4: Sumeragi  2017
# 231                                    Just Dance 2014  2015
# 86                                          Until Dawn  2017
# 604                                Winning Post 8 2018  2018
# ...

# %% [markdown]
# ### 3.1.2-Random sampling with replacement

# %%
random_sample = df.sample(n = 20, replace = True, random_state = 42)
random_sample
# Out:
#                                                   Game  Year  \
# 102                                 Tomb Raider (2013)  2016
# 435                                     Stardew Valley  2019
# 270                                 DmC: Devil May Cry  2017
# 106                              Dragon Ball Fighter Z  2020
# 71                                       Madden NFL 15  2016
# 700        Date-A-Live Twin Edition: Rio Reincarnation  2019
# 20              Uncharted: The Nathan Drake Collection  2017
# 614                                          Road Rage  2019
# 121                                     Mad Max (2013)  2017
# 466                  Agatha Christie's The ABC Murders  2018
# 214                              Skylanders: Trap Team  2016
# 330                  Senran Kagura: Peach Beach Splash  2019
# 458                                            Paragon  2018
# 87                                               Knack  2015
# ...

# %% [markdown]
# ### 3.1.3 Systematic sampling

# %%
index = np.arange(0, len(df),2)
df.iloc[index]
# Out:
#                                             Game  Year             Genre  \
# 0                             Grand Theft Auto V  2016            Action
# 2                          Red Dead Redemption 2  2020  Action-Adventure
# 4                                        FIFA 18  2019            Sports
# 6                                Uncharted (PS4)  2018            Action
# 8                 Call of Duty: Infinite Warfare  2018           Shooter
# ..                                           ...   ...               ...
# 700  Date-A-Live Twin Edition: Rio Reincarnation  2019         Adventure
# 702                     Deception IV: Blood Ties  2017            Action
# 704                          Hyper Light Drifter  2019      Role-Playing
# 706             Darius Burst: Chronicle Saviours  2019            Action
# 708                               Super Meat Boy  2018          Platform
#
#                           Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# ...

# %% [markdown]
# ### 3.1.4 Stratified sampling with respect to Year

# %%
g_d=df.groupby('Year')
eng=df.Year.unique()
strat_sam=pd.DataFrame()

for i in eng:
    s_d=g_d.get_group(i)
    s_d_1=s_d.sample(n=5,random_state=1)
    strat_sam=pd.concat([strat_sam,s_d_1],ignore_index=True)

strat_sam
# Out:
#                                                  Game  Year             Genre  \
# 0                 Lara Croft and the Temple of Osiris  2016            Action
# 1                                           Teslagrad  2016          Platform
# 2                                       Trials Fusion  2016              Misc
# 3                                             Thief 4  2016            Action
# 4                                       The Golf Club  2016            Sports
# 5                                                Ride  2017            Racing
# 6                                     Dead or Alive 5  2017          Fighting
# 7                      Yakuza Zero: The Place of Oath  2017         Adventure
# 8                       The Book of Unwritten Tales 2  2017         Adventure
# 9                            The Witcher 3: Wild Hunt  2017      Role-Playing
# 10                          Dissidia Final Fantasy NT  2020          Fighting
# ...

# %% [markdown]
# ### 3.1.4 Stratified sampling with respect to Genre

# %%
g_d=df.groupby('Genre')
eng=df.Genre.unique()
strat_sam=pd.DataFrame()

for i in eng:
    s_d=g_d.get_group(i)
    s_d_1=s_d.sample(n=5,random_state=1,replace=True)
    strat_sam=pd.concat([strat_sam,s_d_1],ignore_index=True)

strat_sam
# Out:
#                                                  Game  Year         Genre  \
# 0   Dragon Quest Heroes: The World's Tree Woe and ...  2017        Action
# 1                           Unbox: Newbie's Adventure  2019        Action
# 2                                   Attack on Titan 2  2020        Action
# 3                          Vikings: Wolves of Midgard  2019        Action
# 4                 Sengoku Basara: Sanada Yukimura-Den  2018        Action
# ..                                                ...   ...           ...
# 80         Konoyo no Hate de Koi o Utau Shoujo: Yu-No  2019  Visual Novel
# 81                        Ao no Kanata no Four Rhythm  2019  Visual Novel
# 82                                        Root Letter  2018  Visual Novel
# 83                   Psycho-Pass: Mandatory Happiness  2018  Visual Novel
# 84                        Chaos;Child: Love Chu Chu!!  2019  Visual Novel
#
#         Publisher  North_America_Sales_M$  Europe_Sales_M$  Japan_Sales_M$  \
# ...

# %% [markdown]
# ### 3.1.4- Clustered sampling with respect to year

# %%
c_s=df['Year']
cluster_sampling=pd.DataFrame()

for i in c_s:
    s_d1=g_d.get_group(i)
    s_d2=s_d1.sample(frac=0.3,random_state=1)
    cluster_sampling=pd.concat([cluster_sampling,s_d2],ignore_index=True)

cluster_sampling
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 5
#       2 cluster_sampling=pd.DataFrame()
#       4 for i in c_s:
# ----> 5     s_d1=g_d.get_group(i)
#       6     s_d2=s_d1.sample(frac=0.3,random_state=1)
#       7     cluster_sampling=pd.concat([cluster_sampling,s_d2],ignore_index=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1063, in BaseGroupBy.get_group(self, name, obj)
#    1061 inds = self._get_index(name)
#    1062 if not len(inds):
# -> 1063     raise KeyError(name)
#    1065 if obj is None:
#    1066     indexer = inds if self.axis == 0 else (slice(None), inds)
#
# KeyError: 2016

# %%
c_s=df['Genre']
cluster_sampling=pd.DataFrame()

for i in c_s:
    s_d1=g_d.get_group(i)
    s_d2=s_d1.sample(frac=0.3,random_state=1)
    cluster_sampling=pd.concat([cluster_sampling,s_d2],ignore_index=True)

cluster_sampling
# Out:
#                                          Game  Year     Genre  \
# 0                       Samurai Warriors 4-II  2017    Action
# 1                                 Dead Rising  2018    Action
# 2                    Lego Marvel Super Heroes  2015    Action
# 3           Dead Island Definitive Collection  2018    Action
# 4                             Yakuza Kiwami 2  2019    Action
# ...                                       ...   ...       ...
# 17451          Bubsy: The Woolies Strike Back  2019  Platform
# 17452                       Tearaway Unfolded  2017  Platform
# 17453                                   Knack  2015  Platform
# 17454  Wonder Boy: The Dragon's Trap (Remake)  2020  Platform
# 17455                         Mirror's Edge 2  2018  Platform
#
#                                     Publisher  North_America_Sales_M$  \
# 0                                  Tecmo Koei                    0.04
# 1                                      Capcom                    0.04
# ...

# %% [markdown]
# ### 3.2.1- Measure the mean,Median and Standard Deviation

# %%
sample_10 = df.sample(n = 10, replace = True, random_state = 42)
sample_20 = df.sample(n = 20, replace = True, random_state = 42)
sample_30 = df.sample(n = 30, replace = True, random_state = 42)
sample_40 = df.sample(n = 30, replace = True, random_state = 42)

# %% [markdown]
# ### 10-Samples

# %%
def info_cat(col):
    print('Mean for the 10 Sample is', sample_10[col].mean())
    print('Median for the 10 Sample is', sample_10[col].median())
    print('Mode for the 10 Sample is',sample_10[col].mode()[0])
    print('Standard Deviation for the 10 Sample is', st.stdev(sample_10[col]))

# %%
info_cat('Global_Sales_M$')
# Out:
# Mean for the 10 Sample is 1.2650000000000001
# Median for the 10 Sample is 0.755
# Mode for the 10 Sample is 0.01
# Standard Deviation for the 10 Sample is 1.7485057112352314

# %% [markdown]
# ### 20-Samples

# %%
def info_cat(col):
    print('Mean for the 20 Sample is', sample_20[col].mean())
    print('Median for the 20 Sample is', sample_20[col].median())
    print('Mode for the 20 Sample is', sample_20[col].mode()[0])
    print('Standard Deviation for the 20 Sample is', st.stdev(sample_20[col]))

# %%
info_cat('Global_Sales_M$')
# Out:
# Mean for the 20 Sample is 0.9239999999999998
# Median for the 20 Sample is 0.275
# Mode for the 20 Sample is 0.02
# Standard Deviation for the 20 Sample is 1.3401076154744558

# %% [markdown]
# ### 30-Samples

# %%
def info_cat(col):
    print('Mean for the 30 Sample is', sample_30[col].mean())
    print('Median for the 30 Sample is', sample_30[col].median())
    print('Mode for the 30 Sample is', sample_30[col].mode()[0])
    print('Standard Deviation for the 30 Sample is', st.stdev(sample_30[col]))

# %%
info_cat('Global_Sales_M$')
# Out:
# Mean for the 30 Sample is 0.8823333333333333
# Median for the 30 Sample is 0.24
# Mode for the 30 Sample is 0.02
# Standard Deviation for the 30 Sample is 1.4165784015775802

# %% [markdown]
# ### 40-Samples

# %%
def info_cat(col):
    print('Mean for the 40 Sample is', sample_40[col].mean())
    print('Median for the 40 Sample is', sample_40[col].median())
    print('Mode for the 40 Sample is', sample_40[col].mode()[0])
    print('Standard Deviation for the 40 Sample is', st.stdev(sample_40[col]))

# %%
info_cat('Global_Sales_M$')
# Out:
# Mean for the 40 Sample is 0.8823333333333333
# Median for the 40 Sample is 0.24
# Mode for the 40 Sample is 0.02
# Standard Deviation for the 40 Sample is 1.4165784015775802

# %% [markdown]
# ### Sample-population

# %%
def info_cat(col):
    print('Mean for the', col, 'is', df[col].mean())
    print('Median for the', col, 'is', df[col].median())
    print('Mode for the', col, 'is', df[col].mode()[0])
    print('Standard Deviation for the', col, 'is', st.stdev(df[col]))

# %%
info_cat('Global_Sales_M$')
# Out:
# Mean for the Global_Sales_M$ is 0.839802538787024
# Median for the Global_Sales_M$ is 0.17
# Mode for the Global_Sales_M$ is 0.02
# Standard Deviation for the Global_Sales_M$ is 1.853914766367105

# %% [markdown]
# ### 3.2.3- Distribution of Sample

# %% [markdown]
# #### 10-Samples

# %%
sb.distplot(sample_10['Global_Sales_M$'])
# Out:
# C:\Users\boomi\AppData\Local\Temp\ipykernel_6060\4050090871.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(sample_10['Global_Sales_M$'])
# C:\Users\boomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Global_Sales_M$', ylabel='Density'>

# %% [markdown]
# ### Sample-20

# %%
sb.distplot(sample_20['Global_Sales_M$'])
# Out:
# C:\Users\boomi\AppData\Local\Temp\ipykernel_6060\1781977464.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(sample_20['Global_Sales_M$'])
# C:\Users\boomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Global_Sales_M$', ylabel='Density'>

# %% [markdown]
# ### Sample-30

# %%
sb.distplot(sample_30['Global_Sales_M$'])
# Out:
# C:\Users\boomi\AppData\Local\Temp\ipykernel_6060\1688300038.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(sample_30['Global_Sales_M$'])
# C:\Users\boomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Global_Sales_M$', ylabel='Density'>
