# %% [markdown]
# # Sampling Techniques and Distribution

# %% [markdown]
# ## Concept Session

# %% [markdown]
# ## Demo - 3.1: Sampling

# %% [markdown]
# ### Read data from the source file

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import scipy.stats as sts
import statistics as st
from scipy.stats import skew,kurtosis

# %%
df=pd.read_csv("DS1_C5_S3_Employee_Data_Concept.csv")
df
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 0             1010    Male         IT             27000           1   22
# 1             1011  Female         IT             48000           4   27
# 2             1012    Male      Sales             75000          10   31
# 3             1013    Male      Sales             71000           4   29
# 4             1014  Female    Finance             45000           4   27
# ..             ...     ...        ...               ...         ...  ...
# 95            1104    Male    Finance             81250           8   46
# 96            1105    Male      Sales             74580           7   41
# 97            1106  Female         HR             68200           6   36
# 98            1107    Male         IT             54520           7   38
# 99            1108    Male      Sales             74000           7   37
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Extract first 10 records

# %%
df.head(10)
# Out:
#    Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 0            1010    Male         IT             27000           1   22
# 1            1011  Female         IT             48000           4   27
# 2            1012    Male      Sales             75000          10   31
# 3            1013    Male      Sales             71000           4   29
# 4            1014  Female    Finance             45000           4   27
# 5            1015    Male    Finance             40000           0   26
# 6            1016  Female         HR             42000           2   27
# 7            1017    Male         IT             28000           1   23
# 8            1018  Female         IT             48000           4   27
# 9            1019    Male      Sales             75000           4   32

# %% [markdown]
# Observation: There is huge gap between population mean and sample mean, so this sample does not represent properly the population. Do we have any specific technique to extract sample?

# %%
def popul(col):
    print("Mean for the ",col,"is",df[col].mean())
    print("Median for the ",col,"is",df[col].median())
    print("Mode for the ",col,"is",df[col].mode()[0])
    print("Standard Deviation for the ",col,"is",st.stdev(df[col]))

# %%
popul("Annual_Salary($)")
# Out:
# Mean for the  Annual_Salary($) is 62392.6
# Median for the  Annual_Salary($) is 62600.0
# Mode for the  Annual_Salary($) is 48000
# Standard Deviation for the  Annual_Salary($) is 17836.06892753778

# %%
annual_data=sorted(df["Annual_Salary($)"])
print("Kurtosis for annual Salary",kurtosis(annual_data))
# Out:
# Kurtosis for annual Salary -0.309608437858512

# %%
pop_skew=df["Annual_Salary($)"].skew()
print(pop_skew)
# Out:
# -0.059690326690678586

# %%
sb.distplot(df["Annual_Salary($)"])
# Out:
# C:\Users\boomi\AppData\Local\Temp\ipykernel_14700\3017169144.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df["Annual_Salary($)"])
# C:\Users\boomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Annual_Salary($)', ylabel='Density'>

# %% [markdown]
# ## Demo - 3.2: Simple Random Sampling

# %% [markdown]
# ### Simple Random Sampling without Replacement

# %%
random_sample=df.sample(n=20,replace=False,random_state=42)
random_sample
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 83            1092    Male    Finance             75680           4   28
# 53            1062    Male    Finance             78000           9   40
# 70            1079    Male      Sales             78000           6   38
# 45            1054    Male    Finance             63000           4   36
# 44            1053    Male      Sales             58000           9   30
# 39            1048    Male    Finance             55000          10   26
# 22            1032  Female    Finance             30000           4   24
# 80            1089  Female         HR             86000           9   40
# 10            1020    Male      Sales             64000           4   28
# 0             1010    Male         IT             27000           1   22
# 18            1028    Male         HR             36000           0   25
# 30            1040    Male         HR             38000           1   26
# ...

# %% [markdown]
# ### Simple Random Sampling with Replacement

# %%
random_sample=df.sample(n=20,replace=True,random_state=42)
random_sample
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 51            1060    Male    Finance             62700           4   41
# 92            1101  Female    Finance             55840           1   25
# 14            1024  Female         HR             95000           9   35
# 71            1080  Female    Finance             74000           8   32
# 60            1069    Male      Sales             62500           6   30
# 20            1030    Male      Sales             94000           4   37
# 82            1091  Female         IT             59420           4   30
# 86            1095    Male         IT             74580           5   35
# 74            1083  Female      Sales             76000           9   41
# 74            1083  Female      Sales             76000           9   41
# 87            1096    Male    Finance             74150           2   27
# 99            1108    Male      Sales             74000           7   37
# ...

# %% [markdown]
# ### Random Sampling with a fraction of data from Population

# %%
random_sample_40=df.sample(frac=0.4,replace=True,random_state=42)
random_sample_40
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 51            1060    Male    Finance             62700           4   41
# 92            1101  Female    Finance             55840           1   25
# 14            1024  Female         HR             95000           9   35
# 71            1080  Female    Finance             74000           8   32
# 60            1069    Male      Sales             62500           6   30
# 20            1030    Male      Sales             94000           4   37
# 82            1091  Female         IT             59420           4   30
# 86            1095    Male         IT             74580           5   35
# 74            1083  Female      Sales             76000           9   41
# 74            1083  Female      Sales             76000           9   41
# 87            1096    Male    Finance             74150           2   27
# 99            1108    Male      Sales             74000           7   37
# ...

# %% [markdown]
# ## Demo - 3.3: Systematic Sampling

# %%
index=np.arange(0,len(df),2)
df.iloc[index]
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 0             1010    Male         IT             27000           1   22
# 2             1012    Male      Sales             75000          10   31
# 4             1014  Female    Finance             45000           4   27
# 6             1016  Female         HR             42000           2   27
# 8             1018  Female         IT             48000           4   27
# 10            1020    Male      Sales             64000           4   28
# 12            1022    Male         IT             29000           0   22
# 14            1024  Female         HR             95000           9   35
# 16            1026    Male      Sales             64000           4   28
# 18            1028    Male         HR             36000           0   25
# 20            1030    Male      Sales             94000           4   37
# 22            1032  Female    Finance             30000           4   24
# ...

# %% [markdown]
# ## Demo - 3.4: Stratified Sampling

# %%
g_d=df.groupby("Department")
eng=df.Department.unique()
strat_samp=pd.DataFrame()
for i in eng:
    s_d=g_d.get_group(i)
    s_d_1=s_d.sample(n=5,random_state=1)
    strat_samp=pd.concat([strat_samp,s_d_1],ignore_index=True)
strat_samp
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 0             1098    Male         IT             54860           3   28
# 1             1018  Female         IT             48000           4   27
# 2             1071    Male         IT             95400           7   39
# 3             1084    Male         IT             86000           4   28
# 4             1082    Male         IT             79540           4   39
# 5             1059    Male      Sales             60000           9   30
# 6             1083  Female      Sales             76000           9   41
# 7             1075    Male      Sales             58500           6   28
# 8             1079    Male      Sales             78000           6   38
# 9             1099  Female      Sales             78540           5   31
# 10            1085  Female    Finance             62000           4   24
# 11            1062    Male    Finance             78000           9   40
# ...

# %% [markdown]
# ## Demo - 3.5: Cluster Sampling

# %%
c_s=["IT"]
cluster_sampling=pd.DataFrame()
for i in eng:
    s_d1=g_d.get_group(i)
    s_d2=s_d1.sample(frac=0.3,random_state=1)
    cluster_sampling=pd.concat([cluster_sampling,s_d2],ignore_index=True)
cluster_sampling
# Out:
#     Employee_Code   Gender Department  Annual_Salary($)  Experience  Age
# 0             1098    Male         IT             54860           3   28
# 1             1018  Female         IT             48000           4   27
# 2             1071    Male         IT             95400           7   39
# 3             1084    Male         IT             86000           4   28
# 4             1082    Male         IT             79540           4   39
# 5             1073    Male         IT            110000          10   50
# 6             1072  Female         IT             60000           8   42
# 7             1067  Female         IT             90000           9   47
# 8             1036    Male         IT             48000           4   27
# 9             1059    Male      Sales             60000           9   30
# 10            1083  Female      Sales             76000           9   41
# 11            1075    Male      Sales             58500           6   28
# ...

# %% [markdown]
# ## Demo - 3.6: Distribution of Data

# %% [markdown]
# ### Present the distribution of salaries of all employess present in the dataset

# %% [markdown]
# ### Draw the random samples of sizes of 10, 20, and 50

# %%
sample_10 = df.sample(n = 10, replace = True, random_state = 42)
sample_20 = df.sample(n = 20, replace = True, random_state = 42)
sample_50 = df.sample(n = 50, replace = True, random_state = 42)

# %% [markdown]
# ### Present the shape of the distribution of each sample

# %%
sb.distplot(df['Annual_Salary($)'])
# Out:
# C:\Users\boomi\AppData\Local\Temp\ipykernel_14700\4076396840.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['Annual_Salary($)'])
# C:\Users\boomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Annual_Salary($)', ylabel='Density'>

# %%
sb.distplot(sample_10['Annual_Salary($)'])
# Out:
# C:\Users\boomi\AppData\Local\Temp\ipykernel_14700\310648715.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(sample_10['Annual_Salary($)'])
# C:\Users\boomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Annual_Salary($)', ylabel='Density'>

# %%
sb.distplot(sample_20['Annual_Salary($)'])
# Out:
# C:\Users\boomi\AppData\Local\Temp\ipykernel_14700\2533062786.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(sample_20['Annual_Salary($)'])
# C:\Users\boomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Annual_Salary($)', ylabel='Density'>

# %%
sb.distplot(sample_50['Annual_Salary($)'])
# Out:
# C:\Users\boomi\AppData\Local\Temp\ipykernel_14700\1180479569.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(sample_50['Annual_Salary($)'])
# C:\Users\boomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Annual_Salary($)', ylabel='Density'>

# %% [markdown]
# ### Calculate the mean, median, mode, standard deviation, skewness, and kurtosis of population and all sample datasets

# %% [markdown]
# # 10-Samples

# %%
def info_cat(col):
    print('Mean for the 10 Sample is', sample_10[col].mean())
    print('Median for the 10 Sample is', sample_10[col].median())
    print('Mode for the 10 Sample is',sample_50[col].mode()[0])
    print('Standard Deviation for the 10 Sample is', st.stdev(sample_10[col]))

# %%
info_cat('Annual_Salary($)')
# Out:
# Mean for the 10 Sample is 73004.0
# Median for the 10 Sample is 74290.0
# Mode for the 10 Sample is 60000
# Standard Deviation for the 10 Sample is 13506.040788394568

# %%
annual_data=sorted(sample_10['Annual_Salary($)'])
print('Kurtosis for 10 Sample',kurtosis(annual_data))
# Out:
# Kurtosis for 10 Sample -0.8744986168546478

# %%
population_skew=sample_10['Annual_Salary($)'].skew()
print(population_skew)
# Out:
# 0.5716657292382112

# %% [markdown]
# # 20-Samples

# %%
def info_cat(col):
    print('Mean for the 20 Sample is', sample_20[col].mean())
    print('Median for the 20 Sample is', sample_20[col].median())
    print('Mode for the 20 Sample is', sample_20[col].mode()[0])
    print('Standard Deviation for the 20 Sample is', st.stdev(sample_20[col]))

# %%
info_cat('Annual_Salary($)')
# Out:
# Mean for the 20 Sample is 67917.0
# Median for the 20 Sample is 70500.0
# Mode for the 20 Sample is 48000
# Standard Deviation for the 20 Sample is 13741.266355494008

# %%
annual_data=sorted(sample_20['Annual_Salary($)'])
print('Kurtosis for 20 Sample',kurtosis(annual_data))
# Out:
# Kurtosis for 20 Sample -0.17821595463576134

# %%
population_skew=sample_20['Annual_Salary($)'].skew()
print(population_skew)
# Out:
# 0.0903680708172331

# %% [markdown]
# # 30-Samples

# %%
def info_cat(col):
    print('Mean for the 50 Sample is', sample_50[col].mean())
    print('Median for the 50 Sample is', sample_50[col].median())
    print('Mode for the 50 Sample is', sample_50[col].mode()[0])
    print('Standard Deviation for the 50 Sample is', st.stdev(sample_50[col]))

# %%
info_cat('Annual_Salary($)')
# Out:
# Mean for the 20 Sample is 67785.4
# Median for the 20 Sample is 67250.0
# Mode for the 20 Sample is 60000
# Standard Deviation for the 20 Sample is 15619.479231696163

# %%
annual_data=sorted(sample_50['Annual_Salary($)'])
print('Kurtosis for 50 Sample',kurtosis(annual_data))
# Out:
# Kurtosis for 50 Sample -0.6213224695357917

# %%
population_skew=sample_50['Annual_Salary($)'].skew()
print(population_skew)
# Out:
# -0.07966048179798155
