# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("DS1_C4_S4_Test_Scores_Data_Practice.csv")
df
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   school           2133 non-null   object
#  1   school_setting   2133 non-null   object
#  2   school_type      2133 non-null   object
#  3   classroom        2133 non-null   object
#  4   teaching_method  2133 non-null   object
#  5   student_id       2133 non-null   object
#  6   gender           2123 non-null   object
#  7   lunch            2133 non-null   object
#  8   pretest          2129 non-null   float64
#  9   posttest         2129 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 166.8+ KB

# %%
df.describe()
# Out:
#            pretest     posttest
# count  2129.000000  2129.000000
# mean     54.961954    67.111320
# std      13.555995    13.976763
# min      22.000000    32.000000
# 25%      44.000000    56.000000
# 50%      56.000000    68.000000
# 75%      65.000000    77.000000
# max      93.000000   100.000000

# %%
#1
df[df.duplicated(["student_id"],keep = 'first')]
# Out:
# Empty DataFrame
# Columns: [school, school_setting, school_type, classroom, teaching_method, student_id, gender, lunch, pretest, posttest]
# Index: []

# %%
#2
df[df.duplicated(['school_type','teaching_method', 'pretest', 'posttest'], keep='first')]
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# 14    ANKYI          Urban  Non-public       6OL        Standard      MEUC4
# 19    ANKYI          Urban  Non-public       6OL        Standard      ZBQ4T
# 26    ANKYI          Urban  Non-public       ZNS        Standard      AV95M
# 35    ANKYI          Urban  Non-public       ZNS        Standard      OGW1F
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
# ...

# %%
#3
high=(df.groupby('school').agg({"pretest":{"mean"}}))
print([high["pretest"].idxmax()],"\t",[high["pretest"].max()])
# Out:
# [mean    UKPGS
# dtype: object] 	 [mean    78.453125
# dtype: float64]

# %%
#4
df.groupby(["school_setting","gender"])[["gender"]].count()
# Out:
#                        gender
# school_setting gender
# Rural          Female     228
#                Male       279
# Suburban       Female     368
#                Male       348
# Urban          Female     456
#                Male       444

# %%
#5
max=df.groupby('school').agg({"posttest":{"max","min"}})
print(max)
df.groupby('school').agg({"posttest":"max"}).sort_values(by='posttest', ascending=False).head(5)
# Out:
#        posttest
#             max   min
# school
# ANKYI      79.0  63.0
# CCAAW      91.0  67.0
# CIMBB      88.0  64.0
# CUQAM      76.0  56.0
# DNQDD      79.0  49.0
# FBUMG      88.0  68.0
# GJJHK      85.0  49.0
# GOKXL      77.0  48.0
# GOOBU      64.0  32.0
# IDGFP     100.0  74.0
# KFZMY      67.0  44.0
# KZKKE      62.0  36.0
# LAYPA      84.0  63.0
# OJOBU      84.0  50.0
# QOQTS      85.0  51.0
# UAGPU      83.0  62.0
# UKPGS      99.0  82.0
# UUUQX      91.0  62.0
# VHDHF      77.0  52.0
# VKWQH      82.0  48.0
# VVTVA      62.0  39.0
# ZMNYA      95.0  66.0
# ZOWMK      63.0  43.0
#         posttest
# school
# IDGFP      100.0
# UKPGS       99.0
# ZMNYA       95.0
# UUUQX       91.0
# CCAAW       91.0

# %%
#6
result = df.groupby('school').agg({"pretest": "mean"}).sort_values(by='pretest', ascending=False).head(5)
print(result)
df.groupby('school').agg({"pretest":{"sum","mean"}})
# Out:
#           pretest
# school
# UKPGS   78.453125
# IDGFP   75.202128
# ZMNYA   68.130435
# UUUQX   67.253012
# CIMBB   65.067568
#         pretest
#             sum       mean
# school
# ANKYI    2515.0  61.341463
# CCAAW    7044.0  64.623853
# CIMBB    4815.0  65.067568
# CUQAM    5770.0  53.925234
# DNQDD    6628.0  54.327869
# FBUMG    2893.0  62.891304
# GJJHK    6277.0  53.194915
# GOKXL    3251.0  50.796875
# GOOBU    6005.0  38.248408
# IDGFP    7069.0  75.202128
# KFZMY    2177.0  41.865385
# KZKKE    4136.0  37.261261
# LAYPA    3536.0  62.035088
# OJOBU    4552.0  56.197531
# QOQTS    7774.0  52.527027
# UAGPU    5428.0  62.390805
# UKPGS   10042.0  78.453125
# UUUQX    5582.0  67.253012
# VHDHF    2686.0  52.666667
# VKWQH    5206.0  52.060000
# VVTVA    4063.0  35.955752
# ZMNYA    4701.0  68.130435
# ZOWMK    4864.0  41.572650

# %%
#7
scholarship=df[(df.school=="FBUMG")&(df.classroom=="5LQ")].loc[:,["student_id","posttest"]]
scholarship
# Out:
#     student_id  posttest
# 467      04DG5      84.0
# 468      20M2D      85.0
# 469      39KCW      81.0
# 470      5Z1B6      88.0
# 471      6TLU8      81.0
# 472      ATQQJ      82.0
# 473      AYEU1      79.0
# 474      B9FSU      83.0
# 475      EV13K      83.0
# 476      I5H37      83.0
# 477      JC5I9      80.0
# 478      JPE2J      81.0
# 479      MFBYU      82.0
# 480      O144X      86.0
# 481      OGKP3      83.0
# 482      UMFI7      73.0
# 483      V1DNJ      76.0
# 484      YRN9S      87.0

# %%
values=scholarship.posttest*100
scholarship["scholarship_Amount"]=values
scholarship
# Out:
#     student_id  posttest  scholarship_Amount
# 467      04DG5      84.0              8400.0
# 468      20M2D      85.0              8500.0
# 469      39KCW      81.0              8100.0
# 470      5Z1B6      88.0              8800.0
# 471      6TLU8      81.0              8100.0
# 472      ATQQJ      82.0              8200.0
# 473      AYEU1      79.0              7900.0
# 474      B9FSU      83.0              8300.0
# 475      EV13K      83.0              8300.0
# 476      I5H37      83.0              8300.0
# 477      JC5I9      80.0              8000.0
# 478      JPE2J      81.0              8100.0
# 479      MFBYU      82.0              8200.0
# 480      O144X      86.0              8600.0
# 481      OGKP3      83.0              8300.0
# 482      UMFI7      73.0              7300.0
# 483      V1DNJ      76.0              7600.0
# 484      YRN9S      87.0              8700.0

# %%
#8
df.replace(to_replace = ['Qualifies for reduced/free lunch','Does not qualify' ], value = ['Yes','No'])
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender lunch  pretest  posttest
# ...

# %%
#9
pd.crosstab(df.school_setting, df.teaching_method)
# Out:
# teaching_method  Experimental  Standard
# school_setting
# Rural                     201       309
# Suburban                  284       433
# Urban                     275       631

# %%
#10
df.loc[(df.posttest <= 39) & (df.gender == 'male'), 'pretest'] = 135
df
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
# ...

# %%
#11
pd.pivot_table(df, index=['school_setting'], columns = ['gender'], values = ['posttest'], aggfunc = ['mean'])
# Out:
#                      mean
#                  posttest
# gender             Female       Male
# school_setting
# Rural           63.973568  64.032258
# Suburban        76.049046  75.942529
# Urban           61.149780  62.421171

# %%
# Replace NaN values in the 'gender' column with 'male'
#df['gender'].fillna(92, inplace=True)

# %%
#df['new gender']=92

# %%
#df['gender'].notna()

# %%
df[['gender']].tail()
# Out:
#       gender
# 2128  Female
# 2129  Female
# 2130  Female
# 2131    Male
# 2132    Male

# %%
mode_value=df[df['gender'].notna()]['gender'].mode()[0]

# %%
mode_value
# Out:
# 'Male'

# %%
df['value']=df.gender .fillna(df.gender .mode()[0])

# %%
df[['gender','value']]
# Out:
#       gender   value
# 0     Female  Female
# 1     Female  Female
# 2       Male    Male
# 3     Female  Female
# 4       Male    Male
# ...      ...     ...
# 2128  Female  Female
# 2129  Female  Female
# 2130  Female  Female
# 2131    Male    Male
# 2132    Male    Male
#
# [2133 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# school              0
# school_setting      0
# school_type         0
# classroom           0
# teaching_method     0
# student_id          0
# gender             10
# lunch               0
# pretest             4
# posttest            4
# dtype: int64

# %%
#12
df.gender  = df.gender .fillna(df.gender .mode()[0])
df.pretest = df.pretest.fillna(df.pretest.mode()[0])
df.posttest = df.posttest.fillna(df.posttest.mode()[0])

# %%
df.isnull().sum()
# Out:
# school             0
# school_setting     0
# school_type        0
# classroom          0
# teaching_method    0
# student_id         0
# gender             0
# lunch              0
# pretest            0
# posttest           0
# dtype: int64

# %% [markdown]
# # Challenge

# %%
df2=pd.read_csv("DS1_C4_S4_Car_Prices_Data_Challenge.csv")
df2
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493484 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558836 non-null  object
#  8   condition     547043 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  int64
#  14  sellingprice  558837 non-null  int64
#  15  saledate      558812 non-null  object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 68.2+ MB

# %%
df2[(df2.body=="SUV")]
# Out:
#         year  make           model                       trim body  \
# 0       2015   Kia         Sorento                         LX  SUV
# 1       2015   Kia         Sorento                         LX  SUV
# 13      2015   Kia         Sorento                         LX  SUV
# 17      2014  Audi              Q5  2.0T Premium Plus quattro  SUV
# 28      2014   BMW              X5                  sDrive35i  SUV
# ...      ...   ...             ...                        ...  ...
# 558805  2012  Jeep  Grand Cherokee                     Laredo  SUV
# 558821  2012  Ford          Escape                        XLT  SUV
# 558826  2014  Jeep  Grand Cherokee                    Limited  SUV
# 558827  2014  Jeep  Grand Cherokee                     Laredo  SUV
# 558834  2012   BMW              X5                  xDrive35d  SUV
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df2.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547043.000000  558743.000000  558837.000000
# mean     2010.038927       3.424511   68320.437548   13769.319811
# std         3.966864       0.949462   53398.058707    9679.649690
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000       2.700000   28371.000000    7100.000000
# 50%      2012.000000       3.600000   52254.000000   12250.000000
# 75%      2013.000000       4.200000   99109.000000   18300.000000
# max      2015.000000       5.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558837.000000
# mean    13611.207538
# std      9749.444610
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# max    230000.000000

# %%
#1
low=df2[(df2.year==2014)]
low.sort_values("sellingprice",ascending=True).head()
# Out:
#         year      make         model      trim          body transmission  \
# 293223  2014      Ford  E-Series Van     E-250  E-Series Van    automatic
# 185680  2014  Chrysler           200        LX         Sedan    automatic
# 405960  2014      Ford        Escape  Titanium           SUV    automatic
# 174198  2014    Nissan         Versa    1.6 SV         Sedan    automatic
# 174145  2014   Hyundai    Elantra GT      Base     Hatchback    automatic
#
#                       vin state  condition  odometer  color interior  \
# 293223  1ftne2ew6eda13643    tx        4.1   31886.0  white     gray
# 185680  1c3ccbab7en125253    ca        1.0   16973.0  white    black
# 405960  1fmcu9j94eua96505    nj        4.4   20074.0    red    black
# 174198  3n1cn7ap1el855595    il        1.9   15091.0   gray    black
# 174145  kmhd35lh9eu165404    in        2.0       1.0    red    black
#
#                                                    seller    mmr  \
# ...

# %%
#2
Y1=df2[(df2.year==2010) &(df2.make=="BMW")&(df2.condition>4.5)]
Y2=df2[(df2.year==2015) &(df2.make=="BMW")]
avg1=Y1["sellingprice"].mean()
avg2=Y2["sellingprice"].mean()
comparevalue=((avg2-avg1)/avg1)*100
print("2010 Average vale",avg1)
print("2015 Average vale",avg2)
print("precentage of selling cars",comparevalue)
# Out:
# 2010 Average vale 23572.222222222223
# 2015 Average vale 42937.234042553195
# precentage of selling cars 82.15182954653724

# %%
Y1
# Out:
#         year make                  model          trim         body  \
# 43927   2010  BMW               3 Series          328i        Coupe
# 70751   2010  BMW               3 Series          328i        Sedan
# 114558  2010  BMW               6 Series          650i  Convertible
# 114559  2010  BMW               3 Series   328i xDrive        Sedan
# 126368  2010  BMW                     M3          Base        Coupe
# 135141  2010  BMW                     X5     xDrive35d          SUV
# 153657  2010  BMW               3 Series          335d        Sedan
# 153661  2010  BMW               7 Series   750i xDrive        Sedan
# 194514  2010  BMW               5 Series          535i        Sedan
# 226562  2010  BMW               7 Series         750Li        Sedan
# 251236  2010  BMW               3 Series          328i  Convertible
# 251237  2010  BMW                     X3     xDrive30i          SUV
# 258240  2010  BMW               5 Series          528i        Sedan
# ...

# %%
#3
C1=df2[(df2.interior=="black")]
C2=df2[(df2.interior=="gray")]
B1=C1["mmr"].mean()
G1=C2["mmr"].mean()
print("average black interior car",B1)
print("average gray interior car",G1)
# Out:
# average black interior car 15858.52005549485
# average gray interior car 11189.776545228522

# %%
#4
sold=df2[df2["year"].between(2013,2015)]
sold.groupby(['make', 'color'])[['color']].count()
# Out:
#                      color
# make       color
# Acura      black       170
#            blue         19
#            brown         5
#            burgundy     20
#            charcoal      2
# ...                    ...
# volkswagen —             1
# vw         black         1
#            gray          1
#            white         1
#            —            10
#
# [550 rows x 1 columns]

# %%
#5
body1=df2[(df2.body=="SUV")&(df2.saledate=="Fri Dec 19 2014 09:00:00 GMT-0800 (PST)")].loc[:,["sellingprice"]].mean()
body2=df2[(df2.body=="SUV")&(df2.saledate=="Thu Jan 15 2015 04:30:00 GMT-0800 (PST)")].loc[:,["sellingprice"]].mean()
comparevalue=((body2-body1)/body2)*100
print(comparevalue)
# Out:
# sellingprice    41.610331
# dtype: float64

# %%
df2.loc[:,["sellingprice"]]
# Out:
#         sellingprice
# 0              21500
# 1              21500
# 2              30000
# 3              27750
# 4              67000
# ...              ...
# 558832         33000
# 558833         30800
# 558834         34000
# 558835         11100
# 558836         26700
#
# [558837 rows x 1 columns]

# %%
#6
df2.insert(15,"Discountedprice",np.nan,True)
df2
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df2.loc[(df2.make!="Ford"),["Discountedprice"]]=df2.sellingprice*0.8
df2.loc[(df2.make=="chevrolet"),["Discountedprice"]]=df2.sellingprice*0.9
df2.loc[(df2.make=="Ford"),["Discountedprice"]]=df2.sellingprice*0.8
df2
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
#7
df2.drop("saledate",axis=1,inplace=True)
df2.drop("vin",axis=1,inplace=True)

# %%
#8
df2.isnull().sum()
# Out:
# year                   0
# make               10301
# model              10399
# trim               10651
# body               13195
# transmission       65353
# state                  1
# condition          11794
# odometer              94
# color                749
# interior             749
# seller                 0
# mmr                    0
# sellingprice           0
# Discountedprice        0
# dtype: int64

# %%
df2.make = df2.make.fillna(df2.make.mode()[0])
df2.model = df2.model.fillna(df2.model.mode()[0])
df2.trim = df2.trim.fillna(df2.trim.mode()[0])
df2.body = df2.body.fillna(df2.body.mode()[0])
df2.transmission = df2.transmission.fillna(df2.transmission.mode()[0])
df2.state = df2.state.fillna(df2.state.mode()[0])
df2.condition = df2.condition.fillna(df2.condition.mode()[0])
df2.odometer = df2.odometer.fillna(df2.odometer.mode()[0])
df2.color = df2.color.fillna(df2.color.mode()[0])
df2.interior = df2.interior.fillna(df2.interior.mode()[0])

# %%
df2.isnull().sum()
# Out:
# year               0
# make               0
# model              0
# trim               0
# body               0
# transmission       0
# state              0
# condition          0
# odometer           0
# color              0
# interior           0
# seller             0
# mmr                0
# sellingprice       0
# Discountedprice    0
# dtype: int64
