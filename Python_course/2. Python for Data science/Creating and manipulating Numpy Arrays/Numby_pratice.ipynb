# %%
import numpy as np

# %%
#1
Hr_department=np.arange(1,501)
Finance_department=np.arange(501,1001)
IT_Department=np.arange(1001,1501)
Sales_department=np.arange(1501,2001)

# %%
#2
from numpy import random
hr_salary=np.random.randint(25000,50000,size=500)
Finance_Sal=hr_salary*1.25
Sales_sal=Finance_Sal/2
IT_sal=hr_salary+5000

# %%
total_hr=np.sum(hr_salary)
total_Fin=np.sum(Finance_Sal)
total_IT=np.sum(Sales_sal)
total_Sales=np.sum(IT_sal)

Find_costing={"hr_Depart":total_hr,"fin_Depart":total_Fin,"IT_Depart":total_IT,"Sales_Depart":total_Sales}
More_costing=max(Find_costing,key=Find_costing.get)
print(Find_costing)
print("the department costing the company more -",More_costing)
# Out:
# {'hr_Depart': 18899872, 'fin_Depart': 23624840.0, 'IT_Depart': 12993662.0, 'Sales_Depart': 21399872}
# the department costing the company more - hr_Depart

# %%
Find_costing
# Out:
# {'hr_Depart': 18899872,
#  'fin_Depart': 23624840.0,
#  'IT_Depart': 11812420.0,
#  'Sales_Depart': 21399872}

# %%
#4
high_hr=np.sort(hr_salary)[::-1]
ten_hr=[high_hr[:10]]
high_Fin=np.sort(Finance_Sal)[::-1]
ten_Fin=[high_Fin[:10]]
print("Higest salary of HR Department",ten_hr)
print()
print("Higest salary of Finance Department",ten_Fin)
# Out:
# Higest salary of HR Department [array([49950, 49906, 49883, 49662, 49413, 49347, 49321, 49276, 49276,
#        49267])]
#
# Higest salary of Finance Department [array([62437.5 , 62382.5 , 62353.75, 62077.5 , 61766.25, 61683.75,
#        61651.25, 61595.  , 61595.  , 61583.75])]

# %%
#5
Annual_Sales=Sales_sal>45000
Annual_IT=IT_sal>45000
no_Sal=np.sum(Annual_Sales)
no_IT=np.sum(Annual_IT)
print("Annual Salary more than 40,000 in Sales",no_Sal)
print("Annual Salary more than 40,000 in IT",no_IT)
# Out:
# Annual Salary more than 40,000 in Sales 0
# Annual Salary more than 40,000 in IT 217

# %%
#6
less_sales=Sales_sal<45000
num_sales=np.sum(less_sales)
Sales_sal[less_sales]*=1.10
print(Sales_sal[less_sales])
# Out:
# [35659.30847875 43120.90196563 28187.74996125 33273.23725688
#  32534.717765   34025.04345625 41207.61608563 40174.5745775
#  48503.12572875 43254.87626625 41171.07764    40649.57437063
#  47901.90221438 27928.659165   45590.01510938 49247.18134875
#  36062.33860625 38601.20696438 44134.0134125  47423.58074438
#  36774.28468313 43336.8109625  35550.8003675  29441.12936875
#  37286.9301475  43292.5219375  31582.5037275  30776.4434725
#  28755.75670688 33071.72219313 28625.10408313 41774.51560563
#  31511.6412875  32851.38429375 41792.23121563 41848.6997225
#  31793.98382188 32067.46855125 28942.8778375  30032.3878525
#  48098.98837563 43852.77810375 48517.51966188 40755.86803063
#  31385.41756625 36095.555375   48206.38926125 49377.8339725
#  43918.10441563 33695.09022    29148.82180375 29482.09671688
#  36882.79279438 39733.89877875 44174.98076063 43253.76904063
#  27782.5053825  47381.50617063 32968.75021    30291.47864875
# ...

# %%
Sales_sal
# Out:
# array([24355.7875 , 29452.15625, 19252.6125 , 22726.06875, 22221.65   ,
#        35649.625  , 23239.5625 , 36967.0125 , 28145.35625, 27439.775  ,
#        33128.2875 , 29543.6625 , 28120.4    , 27764.20625, 34541.71875,
#        32717.64375, 19075.65   , 31138.59375, 33636.4875 , 34087.2125 ,
#        24631.0625 , 26365.14375, 30144.125  , 36462.59375, 32390.94375,
#        25117.33125, 29599.625  , 24281.675  , 20108.6875 , 25467.475  ,
#        29569.375  , 21571.275  , 21020.725  , 19640.56875, 22588.43125,
#        19551.33125, 37556.8875 , 28532.55625, 21522.875  , 22437.9375 ,
#        28544.65625, 36921.6375 , 36957.9375 , 28583.225  , 21715.71875,
#        21902.5125 , 35656.43125, 19768.375  , 36765.85   , 20512.525  ,
#        32852.25625, 29952.0375 , 33138.11875, 35310.06875, 27836.80625,
#        21436.6625 , 34587.85   , 24653.75   , 32925.6125 , 33725.725  ,
#        29996.65625, 23014.2    , 19909.0375 , 35771.38125, 20136.66875,
# ...
