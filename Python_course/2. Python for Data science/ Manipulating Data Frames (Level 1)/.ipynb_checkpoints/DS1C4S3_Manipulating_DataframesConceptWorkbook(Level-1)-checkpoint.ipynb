# %% [markdown]
# ## Pandas data table
# ![01_table_dataframe.svg](attachment:01_table_dataframe.svg)![Screenshot 2024-03-26 125420.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # Manipulating Data Frames (Level 1)

# %% [markdown]
# # Concept Session

# %% [markdown]
# # MacPizza, one of the famous pizzerias in Unites States, has the data of its pizza sales for the last few years. The manager wants to analyze the past data for business growth, which is available in different file formats.
#
# ## Help the manager to perform various tasks to accomplish the goal.

# %% [markdown]
# # Task 1)

# %% [markdown]
# ## The manager wants to read the data available in CSV file format. Help the manager to accomplish the task.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/DS1_C4_S3_BigMarket_Data_Concept.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv("/content/DS1_C4_S3_BigMarket_Data_Concept.csv")
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/DS1_C4_S3_BigMarket_Data_Concept.csv'

# %% [markdown]
# ## Each column in a DataFrame is a Series
# ![01_table_series.svg](attachment:01_table_series.svg)

# %%
df.shape

# %%
df.ndim

# %%
df.info()

# %%
df.describe()     #Summary of numerical values in the column

# %%
df.head()  #Prints first 5 rows

# %%
df.tail()    #Prints last 5 rows

# %% [markdown]
# ## Task 2)

# %% [markdown]
# ## The manager wants to read the data available in Excel file format.

# %%
df1 = pd.read_excel("/content/DS1_C4_S3_BigMarket_Data_Concept.xlsx")

# %%
df1

# %%
df1.columns

# %%
df1.index

# %% [markdown]
# # Task 3)

# %% [markdown]
# ## The manager wants to read the data available in text file format.

# %%
df2 = pd.read_csv("/content/DS1_C4_S3_BigMarket_Data_Concept.txt", sep='\t')

# %%
df2

# %% [markdown]
# # Task 4)

# %% [markdown]
# ## The company has generated high revenue from the sales of pizzas online. Help the manager to read the data in HTML file format.

# %%
df3 = pd.read_html("/content/DS1_C4_S3_BigMarket_Data_Concept.html")

# %%
type(df3)

# %% [markdown]
# # Task 5)

# %% [markdown]
# ## a) Find the total number of rows and columns in input data.

# %%
df1.shape

# %% [markdown]
# ### First entry indicates number of rows and second one indicates number of columns.

# %% [markdown]
# ## b) Find the information about data types, shapes, and null values in input data.

# %%
df1.info()

# %% [markdown]
# # Pandas dtypes
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Task 6)

# %% [markdown]
# ## The manager wants to check few specific entries of data.

# %% [markdown]
# ### .iloc: Integer-location based indexing for selection by position (from 0 to length-1 of the axis)
# ### Thus, [11:16] returns row numbers 11 to 16-1

# %%
df.iloc[11:17,:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.iloc[11:17,:2]
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Task 7)

# %% [markdown]
# ## The manager wants to check the entries for 'Store' only.
# ### a) Method 1

# %%
df.loc[:,['Store']]
# Out:
#    Store
# 0      A
# 1      B
# 2      C
# 3      D
# 4      E
# 5      A
# 6      B
# 7      C
# 8      D
# 9      E
# 10     A
# 11     B
# 12     C
# 13     D
# 14     E
# 15     A
# 16     B
# 17     C
# 18     D
# 19     E
# 20     A
# 21     B
# 22     C
# 23     D
# 24     E

# %%
df[["Store"]]
# Out:
#    Store
# 0      A
# 1      B
# 2      C
# 3      D
# 4      E
# 5      A
# 6      B
# 7      C
# 8      D
# 9      E
# 10     A
# 11     B
# 12     C
# 13     D
# 14     E
# 15     A
# 16     B
# 17     C
# 18     D
# 19     E
# 20     A
# 21     B
# 22     C
# 23     D
# 24     E

# %% [markdown]
# ### The last five rows for 'Store' column have been displayed.
# ### b) Method 2

# %%
df.tail()[['Store']]
# Out:
#    Store
# 20     A
# 21     B
# 22     C
# 23     D
# 24     E

# %% [markdown]
# # Task 8)

# %% [markdown]
# ## The manager needs information of the stores where the sales are more than a specific number.

# %% [markdown]
# ### The entries are extracted where sales are more than 45000.

# %%
df[df.Sales > 45000]
# Out:
#     Month Store  Sales
# 9     Feb     E  46267
# 12  March     C  47814
# 17    Apr     C  47488
# 22    May     C  46482
# 23    May     D  46313
# 24    May     E  47594

# %% [markdown]
# # Task 9)

# %% [markdown]
# ## The manager needs information of stores where the sales are less than a specific number. Help the manager to accomplish this for a particular month.

# %% [markdown]
# ### The entries are extracted where sales are less than 30000 in January.

# %%
df[(df.Month=='Jan') & (df.Sales < 30000)][["Store","Sales"]]
# Out:
#   Store  Sales
# 1     B  20722
# 2     C  24557
# 4     E  29795

# %%
df[(df.Month=='Jan') & (df.Sales < 30000)].loc[:, ['Store', 'Sales']]
# Out:
#   Store  Sales
# 1     B  20722
# 2     C  24557
# 4     E  29795

# %% [markdown]
# # Task 10)

# %% [markdown]
# ## The manager wants to offer bonus to the best stores to encourage high sales. He wants to select the top 5 stores with the highest sales record.
# ### Sorting sales in descending order first

# %%
df.sort_values('Sales', ascending=False).head()
# Out:
#     Month Store  Sales
# 12  March     C  47814
# 24    May     E  47594
# 17    Apr     C  47488
# 22    May     C  46482
# 23    May     D  46313

# %% [markdown]
# ### Now, displaying the top 5 entries

# %% [markdown]
# # Task 11)

# %% [markdown]
# ## The manager wants to access the sales in ascending order of 'Store' and 'Sales' values. How can the manager accomplish the task?

# %%
df.sort_values(['Store', 'Sales'])
# Out:
#     Month Store  Sales
# 15    Apr     A  27253
# 5     Feb     A  29133
# 20    May     A  29487
# 0     Jan     A  31037
# 10  March     A  32961
# 1     Jan     B  20722
# 6     Feb     B  22695
# 11  March     B  26451
# 21    May     B  40001
# 16    Apr     B  40241
# 2     Jan     C  24557
# 7     Feb     C  28312
# 22    May     C  46482
# 17    Apr     C  47488
# 12  March     C  47814
# 18    Apr     D  25432
# 8     Feb     D  31454
# 3     Jan     D  34649
# 13  March     D  36069
# 23    May     D  46313
# 4     Jan     E  29795
# 14  March     E  31874
# 19    Apr     E  33880
# 9     Feb     E  46267
# 24    May     E  47594

# %%
df.sort_values(['Store', 'Sales'], ascending = [True, False])
# Out:
#     Month Store  Sales
# 10  March     A  32961
# 0     Jan     A  31037
# 20    May     A  29487
# 5     Feb     A  29133
# 15    Apr     A  27253
# 16    Apr     B  40241
# 21    May     B  40001
# 11  March     B  26451
# 6     Feb     B  22695
# 1     Jan     B  20722
# 12  March     C  47814
# 17    Apr     C  47488
# 22    May     C  46482
# 7     Feb     C  28312
# 2     Jan     C  24557
# 23    May     D  46313
# 13  March     D  36069
# 3     Jan     D  34649
# 8     Feb     D  31454
# 18    Apr     D  25432
# 24    May     E  47594
# 9     Feb     E  46267
# 19    Apr     E  33880
# 14  March     E  31874
# 4     Jan     E  29795

# %% [markdown]
# # Task 12)

# %% [markdown]
# ## The manager has found more records for a particular month. How can the manager add these new entries to the existing data?
# ### Method 1

# %%
dic = {'Month':['June', "July"],
       "Store":['A','B'],
       "Sales":[24000,32260]}

df_dic = pd.DataFrame(dic)

# %%
df_n = df.append(df_dic, ignore_index=True)
# Out:
# <ipython-input-44-4f13fb612a67>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_n = df.append(df_dic, ignore_index=True)

# %%
df_n
# Out:
#     Month Store  Sales
# 0     Jan     A  31037
# 1     Jan     B  20722
# 2     Jan     C  24557
# 3     Jan     D  34649
# 4     Jan     E  29795
# 5     Feb     A  29133
# 6     Feb     B  22695
# 7     Feb     C  28312
# 8     Feb     D  31454
# 9     Feb     E  46267
# 10  March     A  32961
# 11  March     B  26451
# 12  March     C  47814
# 13  March     D  36069
# 14  March     E  31874
# 15    Apr     A  27253
# 16    Apr     B  40241
# 17    Apr     C  47488
# 18    Apr     D  25432
# 19    Apr     E  33880
# 20    May     A  29487
# 21    May     B  40001
# 22    May     C  46482
# 23    May     D  46313
# 24    May     E  47594
# 25   June     A  24000
# 26   July     B  32260

# %% [markdown]
# ### New entries have been displayed

# %% [markdown]
# ### Data has been displayed with the new entries added.
#
# ### Method 2

# %%
df_1 = pd.concat([df, df_dic],ignore_index=True)

# %%
df_1
# Out:
#     Month Store  Sales
# 0     Jan     A  31037
# 1     Jan     B  20722
# 2     Jan     C  24557
# 3     Jan     D  34649
# 4     Jan     E  29795
# 5     Feb     A  29133
# 6     Feb     B  22695
# 7     Feb     C  28312
# 8     Feb     D  31454
# 9     Feb     E  46267
# 10  March     A  32961
# 11  March     B  26451
# 12  March     C  47814
# 13  March     D  36069
# 14  March     E  31874
# 15    Apr     A  27253
# 16    Apr     B  40241
# 17    Apr     C  47488
# 18    Apr     D  25432
# 19    Apr     E  33880
# 20    May     A  29487
# 21    May     B  40001
# 22    May     C  46482
# 23    May     D  46313
# 24    May     E  47594
# 25   June     A  24000
# 26   July     B  32260

# %% [markdown]
# # Task 13)

# %% [markdown]
# ## The company has its stores in five different states of US, namely 'Alaska', 'Texas', 'California', 'Montana', and 'New Mexico'. How can the manager add a new column that includes these five states?

# %%
df
# Out:
#     Month Store  Sales
# 0     Jan     A  31037
# 1     Jan     B  20722
# 2     Jan     C  24557
# 3     Jan     D  34649
# 4     Jan     E  29795
# 5     Feb     A  29133
# 6     Feb     B  22695
# 7     Feb     C  28312
# 8     Feb     D  31454
# 9     Feb     E  46267
# 10  March     A  32961
# 11  March     B  26451
# 12  March     C  47814
# 13  March     D  36069
# 14  March     E  31874
# 15    Apr     A  27253
# 16    Apr     B  40241
# 17    Apr     C  47488
# 18    Apr     D  25432
# 19    Apr     E  33880
# 20    May     A  29487
# 21    May     B  40001
# 22    May     C  46482
# 23    May     D  46313
# 24    May     E  47594

# %% [markdown]
# ### As you can see, a new column has been created, titled 'State', which has 30 rows and 5 distinct states.
# ### Now, let's add this new column to input data.

# %%
l = ['Alaska', 'Texas', 'California', 'Montana', 'New Mexico']
l1 = l*5

# %%
df['State'] = l1

# %%
df
# Out:
#     Month Store  Sales       State
# 0     Jan     A  31037      Alaska
# 1     Jan     B  20722       Texas
# 2     Jan     C  24557  California
# 3     Jan     D  34649     Montana
# 4     Jan     E  29795  New Mexico
# 5     Feb     A  29133      Alaska
# 6     Feb     B  22695       Texas
# 7     Feb     C  28312  California
# 8     Feb     D  31454     Montana
# 9     Feb     E  46267  New Mexico
# 10  March     A  32961      Alaska
# 11  March     B  26451       Texas
# 12  March     C  47814  California
# 13  March     D  36069     Montana
# 14  March     E  31874  New Mexico
# 15    Apr     A  27253      Alaska
# 16    Apr     B  40241       Texas
# 17    Apr     C  47488  California
# 18    Apr     D  25432     Montana
# 19    Apr     E  33880  New Mexico
# 20    May     A  29487      Alaska
# 21    May     B  40001       Texas
# 22    May     C  46482  California
# 23    May     D  46313     Montana
# 24    May     E  47594  New Mexico

# %% [markdown]
# # Task 14)

# %% [markdown]
# ## Help the manager to find the total sales of each state. Which state has the highest sales record?
# ### To find total sales in 'Alaska'

# %%
df[df.State=='Alaska']['Sales'].sum()
# Out:
# 149871

# %%
for i in df.State[:5]:
  a = df[df.State==i]['Sales'].sum()
  print("Sum of total sales in ",i," is ",a)
# Out:
# Sum of total sales in  Alaska  is  149871
# Sum of total sales in  Texas  is  150110
# Sum of total sales in  California  is  194653
# Sum of total sales in  Montana  is  173917
# Sum of total sales in  New Mexico  is  189410

# %% [markdown]
# ### To find total sales in 'Texas'

# %% [markdown]
# ### To find total sales in 'California'

# %% [markdown]
# ### To find total sales in 'Montana'

# %% [markdown]
# ### To find total sales in 'New Mexico'

# %% [markdown]
# ### To find the highest sales record

# %% [markdown]
# # Task 15)

# %% [markdown]
# ## Which steps should the manager follow to compare the performances of the two stores?
# ## Let's compare the sales of the two stores 'B' and 'D'.
# ### a) Extract and display the total number of sales for store B.

# %%
a = df[df.Store=="B"]['Sales'].sum()

# %% [markdown]
# ### b) Extract and display the total number of sales for store D.

# %%
b = df[df.Store=="D"]['Sales'].sum()

# %% [markdown]
# ### c) Now, find the difference between the sales of the two stores and respective percentages.

# %%
((b-a)/b)*100
# Out:
# 13.688713581766015

# %% [markdown]
# ### As you can see, the total sales for store B is 15.304963 % less than the total sales for store D.
# ### In this way, you can compare the sales of two stores.

# %% [markdown]
# # Task 16)

# %% [markdown]
# ## The manager wants to know the number of stores and states in the dataset.

# %%
df['Store'].value_counts()
# Out:
# A    5
# B    5
# C    5
# D    5
# E    5
# Name: Store, dtype: int64

# %%
df['State'].value_counts()
# Out:
# Alaska        5
# Texas         5
# California    5
# Montana       5
# New Mexico    5
# Name: State, dtype: int64

# %% [markdown]
# # Task 17)

# %% [markdown]
# ## The manager wants to replace the values of the entries by some other values. How can the manager perform this task?
# ### Let's replace the sales value '32961' by a new value '33200'.

# %%
df
# Out:
#     Month Store  Sales       State
# 0     Jan     A  31037      Alaska
# 1     Jan     B  20722       Texas
# 2     Jan     C  24557  California
# 3     Jan     D  34649     Montana
# 4     Jan     E  29795  New Mexico
# 5     Feb     A  29133      Alaska
# 6     Feb     B  22695       Texas
# 7     Feb     C  28312  California
# 8     Feb     D  31454     Montana
# 9     Feb     E  46267  New Mexico
# 10  March     A  32961      Alaska
# 11  March     B  26451       Texas
# 12  March     C  47814  California
# 13  March     D  36069     Montana
# 14  March     E  31874  New Mexico
# 15    Apr     A  27253      Alaska
# 16    Apr     B  40241       Texas
# 17    Apr     C  47488  California
# 18    Apr     D  25432     Montana
# 19    Apr     E  33880  New Mexico
# 20    May     A  29487      Alaska
# 21    May     B  40001       Texas
# 22    May     C  46482  California
# 23    May     D  46313     Montana
# 24    May     E  47594  New Mexico

# %%
df['Sales'] = df.Sales.replace(32961,33200)

# %%
df
# Out:
#     Month Store  Sales       State
# 0     Jan     A  31037      Alaska
# 1     Jan     B  20722       Texas
# 2     Jan     C  24557  California
# 3     Jan     D  34649     Montana
# 4     Jan     E  29795  New Mexico
# 5     Feb     A  29133      Alaska
# 6     Feb     B  22695       Texas
# 7     Feb     C  28312  California
# 8     Feb     D  31454     Montana
# 9     Feb     E  46267  New Mexico
# 10  March     A  33200      Alaska
# 11  March     B  26451       Texas
# 12  March     C  47814  California
# 13  March     D  36069     Montana
# 14  March     E  31874  New Mexico
# 15    Apr     A  27253      Alaska
# 16    Apr     B  40241       Texas
# 17    Apr     C  47488  California
# 18    Apr     D  25432     Montana
# 19    Apr     E  33880  New Mexico
# 20    May     A  29487      Alaska
# 21    May     B  40001       Texas
# 22    May     C  46482  California
# 23    May     D  46313     Montana
# 24    May     E  47594  New Mexico

# %% [markdown]
# # Task 18)

# %% [markdown]
# ## The manager needs to update the record of the sales for a particular state. Help the manager to accomplish this task.
#
# ### Let's update the record of 'Sales' in the state of Alaska for the month of March by the new sales value of '35000'.
#
# ### First, display all the records of Alaska state.

# %%
A = df[df.State=='Alaska']
A
# Out:
#     Month Store  Sales   State
# 0     Jan     A  31037  Alaska
# 5     Feb     A  29133  Alaska
# 10  March     A  33200  Alaska
# 15    Apr     A  27253  Alaska
# 20    May     A  29487  Alaska

# %% [markdown]
# ### Then, update record of Alaska for March with new value '35000'.

# %%
A.loc[A.Month=='March', 'Sales']=35000

# %%
A
# Out:
#     Month Store  Sales   State
# 0     Jan     A  31037  Alaska
# 5     Feb     A  29133  Alaska
# 10  March     A  35000  Alaska
# 15    Apr     A  27253  Alaska
# 20    May     A  29487  Alaska

# %%
df[df.State=='Alaska'] = A
df
# Out:
#     Month Store  Sales       State
# 0     Jan     A  31037      Alaska
# 1     Jan     B  20722       Texas
# 2     Jan     C  24557  California
# 3     Jan     D  34649     Montana
# 4     Jan     E  29795  New Mexico
# 5     Feb     A  29133      Alaska
# 6     Feb     B  22695       Texas
# 7     Feb     C  28312  California
# 8     Feb     D  31454     Montana
# 9     Feb     E  46267  New Mexico
# 10  March     A  35000      Alaska
# 11  March     B  26451       Texas
# 12  March     C  47814  California
# 13  March     D  36069     Montana
# 14  March     E  31874  New Mexico
# 15    Apr     A  27253      Alaska
# 16    Apr     B  40241       Texas
# 17    Apr     C  47488  California
# 18    Apr     D  25432     Montana
# 19    Apr     E  33880  New Mexico
# 20    May     A  29487      Alaska
# 21    May     B  40001       Texas
# 22    May     C  46482  California
# 23    May     D  46313     Montana
# 24    May     E  47594  New Mexico

# %% [markdown]
# ### Update the modified record in original input data.

# %% [markdown]
# # Task 19)

# %% [markdown]
# ## a) The manager wants to delete the initial 4 records from the dataset.
# ## b) Also, the manager wants to rename the column 'State' by the new name 'US_State'.
# ### a) To delete first 4 records from the dataset.

# %%
df.drop([0,1,2,4], inplace =True)

# %%
df
# Out:
#     Month Store  Sales       State
# 3     Jan     D  34649     Montana
# 5     Feb     A  29133      Alaska
# 6     Feb     B  22695       Texas
# 7     Feb     C  28312  California
# 8     Feb     D  31454     Montana
# 9     Feb     E  46267  New Mexico
# 10  March     A  35000      Alaska
# 11  March     B  26451       Texas
# 12  March     C  47814  California
# 13  March     D  36069     Montana
# 14  March     E  31874  New Mexico
# 15    Apr     A  27253      Alaska
# 16    Apr     B  40241       Texas
# 17    Apr     C  47488  California
# 18    Apr     D  25432     Montana
# 19    Apr     E  33880  New Mexico
# 20    May     A  29487      Alaska
# 21    May     B  40001       Texas
# 22    May     C  46482  California
# 23    May     D  46313     Montana
# 24    May     E  47594  New Mexico

# %% [markdown]
# ## b) To rename the column 'State' by the new name 'US_State'.

# %%
df.rename(columns={'State':'US_State'}, inplace=True)

# %%
df
# Out:
#     Month Store  Sales    US_State
# 3     Jan     D  34649     Montana
# 5     Feb     A  29133      Alaska
# 6     Feb     B  22695       Texas
# 7     Feb     C  28312  California
# 8     Feb     D  31454     Montana
# 9     Feb     E  46267  New Mexico
# 10  March     A  35000      Alaska
# 11  March     B  26451       Texas
# 12  March     C  47814  California
# 13  March     D  36069     Montana
# 14  March     E  31874  New Mexico
# 15    Apr     A  27253      Alaska
# 16    Apr     B  40241       Texas
# 17    Apr     C  47488  California
# 18    Apr     D  25432     Montana
# 19    Apr     E  33880  New Mexico
# 20    May     A  29487      Alaska
# 21    May     B  40001       Texas
# 22    May     C  46482  California
# 23    May     D  46313     Montana
# 24    May     E  47594  New Mexico

# %% [markdown]
# # Task 20)

# %% [markdown]
# ## The manager wants to know the state-wise sales record for the month of January.

# %%
df[df.Month=='Jan']
# Out:
#   Month Store  Sales US_State
# 3   Jan     D  34649  Montana
