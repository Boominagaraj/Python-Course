# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("DS1_C4_S3_Loan_Data_Practice.csv.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df[(df.Gender=="Male")&(df.Loan_Status=="Y")&(df.Education=="Graduate")]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
df[(df.Gender=="Female")&(df.Self_Employed=="Yes")&(df.ApplicantIncome>4000)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %%
df[(df.Dependents=="3+")&(df.Property_Area=="Rural")&(df.Loan_Status=="Y")]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %%
df["ApplicantIncome"].mean()
# Out:
# 5403.459283387622

# %%
df1=df[(df.Loan_Status=="Y")&(df.LoanAmount>=290)]
print("Average income of previous Customers :",df1["ApplicantIncome"].mean())
df1
# Out:
# Average income of previous Customers : 18641.7
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 21   LP001046    Male     Yes          1  Graduate            No
# 67   LP001233    Male     Yes          1  Graduate            No
# 126  LP001448    Male     Yes         3+  Graduate            No
# 130  LP001469    Male      No          0  Graduate           Yes
# 155  LP001536    Male     Yes         3+  Graduate            No
# 171  LP001585    Male     Yes         3+  Graduate            No
# 260  LP001865    Male     Yes          1  Graduate            No
# 278  LP001907    Male     Yes          0  Graduate            No
# 324  LP002065    Male     Yes         3+  Graduate            No
# 333  LP002101    Male     Yes          0  Graduate            No
# 372  LP002201    Male     Yes          2  Graduate           Yes
# 381  LP002229    Male      No          0  Graduate            No
# 432  LP002386    Male      No          0  Graduate           Yes
# ...

# %%
df2=df[(df.	Married=="No")&(df.Self_Employed=="Yes")&(df.Loan_Status=="N")]
print(df2["Gender"].value_counts())
df2
# Out:
# Gender
# Male      9
# Female    5
# Name: count, dtype: int64
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 95   LP001326    Male      No          0      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 199  LP001673    Male      No          0      Graduate           Yes
# 245  LP001813    Male      No          0      Graduate           Yes
# 254  LP001844    Male      No          0      Graduate           Yes
# 280  LP001910    Male      No          1  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 438  LP002403    Male      No          0      Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# ...

# %%
u=df[(df.Loan_Status=="Y")&(df.Property_Area=="Urban")][["Property_Area","ApplicantIncome"]]
s=df[(df.Loan_Status=="Y")&(df.Property_Area=="Semiurban")][["Property_Area","ApplicantIncome"]]
r=df[(df.Loan_Status=="Y")&(df.Property_Area=="Rural")][["Property_Area","ApplicantIncome"]]
print(u)
print(s)
print(r)
# Out:
#     Property_Area  ApplicantIncome
# 0           Urban             5849
# 2           Urban             3000
# 3           Urban             2583
# 4           Urban             6000
# 5           Urban             5417
# ..            ...              ...
# 594         Urban            16120
# 599         Urban             5780
# 602         Urban             5703
# 611         Urban             8072
# 612         Urban             7583
#
# [133 rows x 2 columns]
#     Property_Area  ApplicantIncome
# 25      Semiurban             9560
# 26      Semiurban             2799
# 29      Semiurban             3750
# 33      Semiurban             3500
# 37      Semiurban             3667
# ..            ...              ...
# 588     Semiurban             4750
# 590     Semiurban             3000
# 592     Semiurban             9357
# 604     Semiurban            12000
# 606     Semiurban             3400
#
# [179 rows x 2 columns]
#     Property_Area  ApplicantIncome
# ...

# %%
df[(df.CoapplicantIncome<df["CoapplicantIncome"].mean())&(df.Married=="Yes")&(df.Loan_Status=="Y")]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 604  LP002959  Female     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
Bank=df[(df.Education=="Graduate")&(df["ApplicantIncome"].between(10256,150000))]
print("Total no of Customer:",Bank["Education"].value_counts())
Bank
# Out:
# Total no of Customer: Education
# Graduate    48
# Name: count, dtype: int64
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 34   LP001100    Male      No         3+  Graduate            No
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 67   LP001233    Male     Yes          1  Graduate            No
# 102  LP001350    Male     Yes          1  Graduate            No
# 106  LP001369    Male     Yes          2  Graduate            No
# 115  LP001401    Male     Yes          1  Graduate            No
# 119  LP001422  Female      No          0  Graduate            No
# 126  LP001448    Male     Yes         3+  Graduate            No
# 128  LP001451    Male     Yes          1  Graduate           Yes
# 130  LP001469    Male      No          0  Graduate           Yes
# 138  LP001492    Male      No          0  Graduate            No
# ...

# %% [markdown]
# # Challenge

# %%
loan=df[(df.ApplicantIncome<=6000)&(df.LoanAmount>200)&(df.Loan_Status=="Y")]
print(loan["Gender"].value_counts())
loan[["Loan_ID","Gender"]]
# Out:
# Gender
# Male      11
# Female     1
# Name: count, dtype: int64
#       Loan_ID  Gender
# 5    LP001011    Male
# 21   LP001046    Male
# 159  LP001552    Male
# 253  LP001843    Male
# 255  LP001846  Female
# 276  LP001903    Male
# 361  LP002170    Male
# 381  LP002229    Male
# 502  LP002615    Male
# 505  LP002622    Male
# 530  LP002717    Male
# 562  LP002820    Male

# %%
u=len(df[df.Property_Area=="Urban"])
s=len(df[df.Property_Area=="Semiurban"])
print("no.of Customers in Semiurban area is",s,"\n No of Customers in urban area is",u)
print("Relative percentage is",(((s-u)/s)*100))
# Out:
# no.of Customers in Semiurban area is 233
#  No of Customers in urban area is 202
# Relative percentage is 13.304721030042918

# %%
highest=df[df.Loan_Status=="Y"]
highest.sort_values("ApplicantIncome",ascending=False).head()
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 333  LP002101   Male     Yes          0  Graduate            No
# 171  LP001585   Male     Yes         3+  Graduate            No
# 155  LP001536   Male     Yes         3+  Graduate            No
# 185  LP001640   Male     Yes          0  Graduate           Yes
# 443  LP002422   Male      No          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 333            63337                0.0         490               180
# 171            51763                0.0         700               300
# 155            39999                0.0         600               180
# 185            39147             4750.0         120               360
# 443            37719                0.0         152               360
#
#      Credit_History Property_Area Loan_Status
# 333               1         Urban           Y
# 171               1         Urban           Y
# ...

# %%
df[(df.Dependents=="2")&(df.Gender=="Female")][["ApplicantIncome","LoanAmount"]]
# Out:
#      ApplicantIncome  LoanAmount
# 29              3750         120
# 82              1378         167
# 146            14866          70
# 219             4283         127
# 251             3427         138
# 293             5417         143
# 468              210          98
# 516             2031         113

# %%
update=df[(df.LoanAmount>=200)&(df.Gender=="Female")]
df["Loan_Amount_Term"]=update.Loan_Amount_Term.replace(360,180)
df[(df.LoanAmount>=200)&(df.Gender=="Female")]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 119  LP001422  Female      No          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 210  LP001708  Female      No          0      Graduate            No
# 233  LP001776  Female      No          0      Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 600  LP002949  Female      No         3+      Graduate           Yes
# 604  LP002959  Female     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 54             11500                0.0         286             180.0
# ...

# %%
df.rename(columns={"Loan_Amount_Term":"LoanAmountTerm"},inplace=True)
df["LoanAmountTerm"]=df.LoanAmountTerm.replace(120,600)
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[198], line 3
#       1 df.rename(columns={"Loan_Amount_Term":"LoanAmountTerm"},inplace=True)
#       2 df["LoanAmountTerm"]=df.LoanAmountTerm.replace(120,600)
# ----> 3 d
#
# NameError: name 'd' is not defined

# %%
credit=df[(df.Education=="Graduate")&(df.ApplicantIncome>=10000)&(df.Self_Employed=="Yes")]
df["Credit_Limit"]=2*credit.ApplicantIncome
df[(df.Education=="Graduate")&(df.ApplicantIncome>=10000)&(df.Self_Employed=="Yes")][["Loan_ID","ApplicantIncome","Credit_Limit"]]
# Out:
#       Loan_ID  ApplicantIncome  Credit_Limit
# 54   LP001186            11500       23000.0
# 128  LP001451            10513       21026.0
# 130  LP001469            20166       40332.0
# 185  LP001640            39147       78294.0
# 199  LP001673            11000       22000.0
# 254  LP001844            16250       32500.0
# 319  LP002050            10000       20000.0
# 370  LP002194            15759       31518.0
# 432  LP002386            12876       25752.0
# 438  LP002403            10416       20832.0
# 475  LP002527            16525       33050.0
# 478  LP002531            16667       33334.0
# 525  LP002699            17500       35000.0
# 557  LP002795            10139       20278.0
# 561  LP002813            19484       38968.0
# 594  LP002938            16120       32240.0

# %%
delete=df[(df.Dependents=="3+")&(df.Credit_History==0)&(df.Education=="Not Graduate")]
df.drop(delete.index,inplace=True)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0               5849                0.0         146             NaN
# ...

# %%
G=df[df.Education=="Graduate"][["Education","ApplicantIncome"]]
N=df[df.Education=="Not Graduate"][["Education","ApplicantIncome"]]
G
# Out:
#     Education  ApplicantIncome
# 0    Graduate             5849
# 1    Graduate             4583
# 2    Graduate             3000
# 4    Graduate             6000
# 5    Graduate             5417
# ..        ...              ...
# 609  Graduate             2900
# 610  Graduate             4106
# 611  Graduate             8072
# 612  Graduate             7583
# 613  Graduate             4583
#
# [480 rows x 2 columns]

# %%
N
# Out:
#         Education  ApplicantIncome
# 3    Not Graduate             2583
# 6    Not Graduate             2333
# 16   Not Graduate             3596
# 18   Not Graduate             4887
# 20   Not Graduate             7660
# ..            ...              ...
# 595  Not Graduate             3833
# 596  Not Graduate             6383
# 601  Not Graduate             2894
# 605  Not Graduate             2400
# 607  Not Graduate             3987
#
# [131 rows x 2 columns]
